# %%
from google.colab import drive

drive.mount('/content/gdrive')
# Out:
# Drive already mounted at /content/gdrive; to attempt to forcibly remount, call drive.mount("/content/gdrive", force_remount=True).

# %%
! git clone https://github.com/tyiannak/pyAudioAnalysis
# Out:
# Cloning into 'pyAudioAnalysis'...
# remote: Enumerating objects: 77, done.
# remote: Counting objects: 100% (77/77), done.
# remote: Compressing objects: 100% (73/73), done.
# remote: Total 1926 (delta 46), reused 23 (delta 4), pack-reused 1849
# Receiving objects: 100% (1926/1926), 81.98 MiB | 10.50 MiB/s, done.
# Resolving deltas: 100% (1152/1152), done.
# Checking out files: 100% (178/178), done.

# %%
cd /content/pyAudioAnalysis
# Out:
# /content/pyAudioAnalysis

# %%
pip install -r ./requirements.txt
# Out:
# ...
#      |████████████████████████████████| 13.8MB 35.1MB/s
# ...
#      |████████████████████████████████| 368kB 39.9MB/s
# ...
#      |████████████████████████████████| 92kB 10.9MB/s
# ...
#      |████████████████████████████████| 153kB 42.3MB/s
# ...
#   Created wheel for simplejson: filename=simplejson-3.17.0-cp36-cp36m-linux_x86_64.whl size=114207 sha256=0c4379cf045ca76ced8f889d71ae1dd6251ae2b81cf14344f44da032dffc7dc7
#   Stored in directory: /root/.cache/pip/wheels/86/c0/83/dcd0339abb2640544bb8e0938aab2d069cef55e5647ce6e097
# Successfully built simplejson
# ERROR: scikit-image 0.15.0 has requirement matplotlib!=3.0.0,>=2.0.0, but you'll have matplotlib 1.5.3 which is incompatible.
# ERROR: plotnine 0.5.1 has requirement matplotlib>=3.0.0, but you'll have matplotlib 1.5.3 which is incompatible.
# ERROR: fbprophet 0.5 has requirement matplotlib>=2.0.0, but you'll have matplotlib 1.5.3 which is incompatible.
# ...

# %%
pip install -e
# Out:
# Usage:
#   pip3 install [options] <requirement specifier> [package-index-options] ...
#   pip3 install [options] -r <requirements file> [package-index-options] ...
#   pip3 install [options] [-e] <vcs project url> ...
#   pip3 install [options] [-e] <local project path> ...
#   pip3 install [options] <archive url/path> ...
#
# -e option requires 1 argument

# %%
# !sudo apt-get install ffmpeg
# Out:
# Reading package lists... Done
# Building dependency tree
# Reading state information... Done
# ffmpeg is already the newest version (7:3.4.6-0ubuntu0.18.04.1).
# The following package was automatically installed and is no longer required:
#   libnvidia-common-430
# Use 'sudo apt autoremove' to remove it.
# 0 upgraded, 0 newly installed, 0 to remove and 7 not upgraded.

# %%
# !sudo apt-get install python3-magic
# Out:
# Reading package lists... Done
# Building dependency tree
# Reading state information... Done
# The following package was automatically installed and is no longer required:
#   libnvidia-common-430
# Use 'sudo apt autoremove' to remove it.
# The following additional packages will be installed:
#   libmagic-mgc libmagic1
# Suggested packages:
#   file
# The following NEW packages will be installed:
#   libmagic-mgc libmagic1 python3-magic
# 0 upgraded, 3 newly installed, 0 to remove and 7 not upgraded.
# Need to get 262 kB of archives.
# After this operation, 5,255 kB of additional disk space will be used.
# Get:1 http://archive.ubuntu.com/ubuntu bionic-updates/main amd64 libmagic-mgc amd64 1:5.32-2ubuntu0.3 [184 kB]
# Get:2 http://archive.ubuntu.com/ubuntu bionic-updates/main amd64 libmagic1 amd64 1:5.32-2ubuntu0.3 [68.7 kB]
# Get:3 http://archive.ubuntu.com/ubuntu bionic/main amd64 python3-magic all 2:0.4.15-1 [9,280 B]
# Fetched 262 kB in 2s (126 kB/s)
# ...

# %%
# !pip install python-magic

# %%
cd /content/pyAudioAnalysis/pyAudioAnalysis
# Out:
# /content/pyAudioAnalysis/pyAudioAnalysis

# %%
! python3 audioAnalysis.py featureExtractionDir -i data/data3/ -mw 1.0 -ms 1.0 -sw 0.050 -ss 0.050
# Out:
# Short-term np file: data/data3/audio3-3.wav_st.npy saved
# Short-term CSV file: data/data3/audio3-3.wav_st.csv saved
# Short-term np file: data/data3/audio3-27.wav_st.npy saved
# Short-term CSV file: data/data3/audio3-27.wav_st.csv saved
# Short-term np file: data/data3/audio3-6.wav_st.npy saved
# Short-term CSV file: data/data3/audio3-6.wav_st.csv saved
# Short-term np file: data/data3/audio3-12.wav_st.npy saved
# Short-term CSV file: data/data3/audio3-12.wav_st.csv saved
# Short-term np file: data/data3/audio3-23.wav_st.npy saved
# Short-term CSV file: data/data3/audio3-23.wav_st.csv saved
# Short-term np file: data/data3/audio3-8.wav_st.npy saved
# Short-term CSV file: data/data3/audio3-8.wav_st.csv saved
# Short-term np file: data/data3/audio3-26.wav_st.npy saved
# Short-term CSV file: data/data3/audio3-26.wav_st.csv saved
# Short-term np file: data/data3/audio3-5.wav_st.npy saved
# Short-term CSV file: data/data3/audio3-5.wav_st.csv saved
# ...

# %%
! python audioAnalysis.py trainClassifier -i data/audio1/ data/child/ data/mother/ --method svm -o data/svm-child-mother-model
# Out:
# Analyzing file 1 of 78: data/child/child1.wav
# Analyzing file 2 of 78: data/child/child10.wav
# Analyzing file 3 of 78: data/child/child11.wav
# Analyzing file 4 of 78: data/child/child13.wav
# Analyzing file 5 of 78: data/child/child14.wav
# Analyzing file 6 of 78: data/child/child15.wav
# Analyzing file 7 of 78: data/child/child16.wav
# Analyzing file 8 of 78: data/child/child17.wav
# Analyzing file 9 of 78: data/child/child18.wav
# Analyzing file 10 of 78: data/child/child19.wav
# Analyzing file 11 of 78: data/child/child2.wav
# Analyzing file 12 of 78: data/child/child20.wav
# Analyzing file 13 of 78: data/child/child21.wav
# Analyzing file 14 of 78: data/child/child22.wav
# Analyzing file 15 of 78: data/child/child23.wav
# Analyzing file 16 of 78: data/child/child24.wav
# Analyzing file 17 of 78: data/child/child25.wav
# Analyzing file 18 of 78: data/child/child26.wav
# Analyzing file 19 of 78: data/child/child27.wav
# Analyzing file 20 of 78: data/child/child28.wav
# ...

# %%
! git clone http://pypi.python.org/pypi/python-magic/
# Out:
# Cloning into 'python-magic'...
# fatal: repository 'http://pypi.python.org/pypi/python-magic/' not found

# %%
from pyAudioAnalysis import audioTrainTest as aT
aT.featureAndTrain(["classifierData/audio1"], 1.0, 1.0, aT.shortTermWindow, aT.shortTermStep, "svm", "svm_speech_audio1", False)
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# <ipython-input-58-e610d336aba0> in <module>()
# ----> 1 from pyAudioAnalysis import audioTrainTest as aT
#       2 aT.featureAndTrain(["classifierData/audio1"], 1.0, 1.0, aT.shortTermWindow, aT.shortTermStep, "svm", "svm_speech_audio1", False)
#
# /content/pyAudioAnalysis/pyAudioAnalysis/audioTrainTest.py in <module>()
#       8 import csv
#       9 import ntpath
# ---> 10 from pyAudioAnalysis import MidTermFeatures as aF
#      11 from pyAudioAnalysis import audioBasicIO
#      12 from scipy import linalg as la
#
# /content/pyAudioAnalysis/pyAudioAnalysis/MidTermFeatures.py in <module>()
#       6 import matplotlib.pyplot as plt
#       7 from pyAudioAnalysis import utilities
# ----> 8 from pyAudioAnalysis import audioBasicIO
#       9 from pyAudioAnalysis import ShortTermFeatures
#      10 eps = 0.00000001
#
# ...

# %%
 # !pwd /content/pyAudioAnalysis/tests
# Out:
# /content/pyAudioAnalysis/tests

# %%
! echo cmd_test_02_B.sh
# Out:
# cmd_test_02_B.sh

# %%
! echo data_root
command="python3 ../pyAudioAnalysis/audioAnalysis.py trainClassifier -i \"${data_root}/audio1\" --method svm_rbf -o svm_audio1  --audio1"
! echo command


#command="python3 ../pyAudioAnalysis/audioAnalysis.py trainClassifier -i \"${data_root}/musicalGenreClassification/Blues\" \"${data_root}/musicalGenreClassification/Classical\" \"${data_root}/musicalGenreClassification/Electronic\" \"${data_root}/musicalGenreClassification/Jazz\" \"${data_root}/musicalGenreClassification/Rap\" \"${data_root}/musicalGenreClassification/Rock\"  --method knn -o knnMusicGenre6  --beat"
#echo $command
#eval $command
# Out:
# data_root
# command
